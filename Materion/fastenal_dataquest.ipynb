# %%
from requests import get
from bs4 import BeautifulSoup
url = 'https://www.fastenal.com/product/abrasives/600948?categoryId=600948&level=1&fsi=1'
response = get(url)
#print(response.text[:500])

# %%
soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
title_containers = soup.findAll('div',class_='gridview__prd--desc')
print(type(title_containers))
print(len(title_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 0

# %%
title_containers
# Out:
# [<div class="col-xs-12 header-menu "> <div class="col-xs-12 navbar-header"> <button class="mobile-search-btn visible-xs"><span class="sprite-icon mobile-search-icon"></span><span class="mobile-search-text">Search</span></button> <a class="fcom-logo" href="/;jsessionid=Ru-45KaYZrH+XbMmoZHAMJMu.38536438-9c19-3947-9017-bf77ad0514fd"><img alt="Fastenal Company" class="screen-only" height="44" src="/static/redesign/images/fastenal-logo-blue-white.png;jsessionid=Ru-45KaYZrH+XbMmoZHAMJMu.38536438-9c19-3947-9017-bf77ad0514fd" width="215"/></a> <div class="navigation hidden-xs hidden-sm"> <ul> <li> <a href="/en/2112/catalogs;jsessionid=Ru-45KaYZrH+XbMmoZHAMJMu.38536438-9c19-3947-9017-bf77ad0514fd">Catalogs</a> </li> <li> <a href="/en/269/rebates-and-flyers;jsessionid=Ru-45KaYZrH+XbMmoZHAMJMu.38536438-9c19-3947-9017-bf77ad0514fd">Rebates &amp; Flyers</a> </li> <li> <a href="/en/1/services-and-resources;jsessionid=Ru-45KaYZrH+XbMmoZHAMJMu.38536438-9c19-3947-9017-bf77ad0514fd">Services &amp; Res
# ...
