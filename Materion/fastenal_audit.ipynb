# %% [markdown]
# # Price Audits - Fastenal

# %% [markdown]
# Project scope -  Create an app that scrapes product information from the Fastenal website. That information will then be used to compare wholesale price, Materion's discounted price, and invoice price to identify variabilities and potential discrepancies.

# %% [markdown]
# ## Import all dependencies and start selenium

# %% [markdown]
# We are using selenium and BeautifulSoup for the scraping process

# %%
#Finding the location of chromedriver.exe
#https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
# Import your newly installed selenium package
from selenium import webdriver
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import time
time.sleep(3)
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import pandas as pd


# Now create an 'instance' of your driver
WebDriver = {'executable_path': 'chromedriver'}

# A new Chrome (or other browser) window should open up
browser = Browser('chrome', **WebDriver, headless=False)

# Defining width and height of the browser
browser.driver.set_window_size(1750, 1250)

#For Mac users - Opening the targer url
#driver.get("https://www.fastenal.com/product/abrasives/coated-and-non-woven-abrasives/fiber-and-sanding-discs/609478?categoryId=609478&level=3&isExpanded=true&productFamilyId=26373")

#For Windows users - Opening the target url
url ='https://www.fastenal.com/product/abrasives/coated-and-non-woven-abrasives/fiber-and-sanding-discs/609478?categoryId=609478&level=3&isExpanded=true&productFamilyId=26373&view=1'
browser.visit(url)

# %% [markdown]
# ## Start the browser and making the soup

# %%
#activating soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## Initialize searches

# %% [markdown]
# ### First we need to create the searches for each piece of information we would like to extract: SKU number, item description, wholesale price, and manufacturer

# %% [markdown]
# #### SKU Number

# %% [markdown]
# Inspecting the website, we found that the SKU number information is in a div inside the class 'media-item-row', and it is consistent across all the pages, so we can create a function that gives us access to that div initially

# %%
#access the sku information in the HTML to create the sku list
sku_list = soup.findAll('div',class_='media-item-row')

#Display the search results
#sku_list

# %% [markdown]
# Now that we were able to access the first record, we can use that code in a nested for loop to extract all of the sku numbers from all pages

# %%
#Creating a loop to extract the description data within the div for page 1 only. 
#This code will be used later in the nested loop

#SKU information
#sku=[]
for view in sku_list:
        #Accessing the div that contains the sku information
        sku3=view('a')
        #Creating a nested loop to extract the specific sku number
        for k in sku3:
            #Accessing the sku information in the anchor tag and stripping spaces
            sku4=sku3[0].text.strip()
            #Appending the sku information to the empty list
            #sku.append(sku4)
            #Print the results
            print(sku4)
#sku
# Out:
# 0826359
#
#
# 0826362
#
#
# 0812730
#
#
#
# 0812777
#
#
#
# 0826357
#
#
# 0812732
#
#
#
# 0802678
#
#
# 0812762
#
#
#
# 0200175
#
#
#
#
#
# 0812767
#
#
#
# 0812733
#
#
#
# 0812738
#
#
#
# 0826359
#
#
# 0826362
#
#
# 0812730
#
#
#
# 0812777
#
#
#
# 0826357
#
#
# 0812732
#
#
#
# 0802678
#
#
# 0812762
#
#
#
# 0200175
#
#
#
# 0812767
#
#
#
# 0812733
#
#
#
# 0812738

# %% [markdown]
# #### Item description

# %% [markdown]
# The item description is not in the same div, so inspecting the website, we found that the the description is inside a div under the class div 'gridview__prd--desc', and it is consistent across all the pages, so we can create a function that gives us access to that div initially

# %%
#access the information in the HTML to create the description list
grid_view = soup.findAll('div',class_='gridview__prd--desc')
#Display the search results and accessing the first record
#grid_view[0]

# %% [markdown]
# After accessing the first record, we can now try the code in a for loop to extract all of the descriptions numbers from page 1

# %%
#Creating a loop to extract the description data within the div for page 1 only. 
#This code will be used later in the nested loop

#Product description
description= []
for view in grid_view:
        #Accessing the description information in the div
        title = view.text
        #Appending the description information to the empty list
        description.append(title)
        #Print the results
        #print(title)
#description
df_desc = pd.DataFrame(description,columns = ['sku'])
df_desc.head()
# Out:
#                                                  sku
# 0       5" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc
# 1       7" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc
# 2  4-1/2" x 7/8" Brown 36 Grit Aluminum Oxide Bla...
# 3  4-1/2" x 7/8" Red/Pink 36 Grit Ceramic Blackst...
# 4   4-1/2" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc

# %% [markdown]
# #### Price

# %% [markdown]
# Price information is not in any of the previous divs, so inspecting the website, we found that the the wholesale price is inside a div under the class div 'color--blue margin-bottom--5', and it is consistent across all the pages, so we can create a function that gives us access to that div initially

# %%
#access the information in the HTML to create the wholesale price list
wholesale_cal = soup.findAll('div',class_='color--blue margin-bottom--5')

#Display the search results and accessing the first record
#wholesale_cal

# %% [markdown]
# After accessing the first record, we can now try the code in a for loop to extract all of the descriptions numbers from page 1

# %%
#Creating a loop to extract the wholesale price data within the div for page 1 only. 
#This code will be used later in the nested loop

#Price
wholesale_price=[]
for sale in wholesale_cal:
        #Accessing the price information in the div
        price = sale('span')
        #Creating a nested loop to extract the specific wholesale price
        for p in price:
            #Accessing the sku information in the anchor tag and stripping spaces
            price2=price[1].text.strip().split('\n')[0].strip("/")
            #Appending the price information to the empty list
            wholesale_price.append(price2)
            #Print the results
            #print(price2)

df_whole_price = pd.DataFrame(wholesale_price,columns = ['wholesale_price'])
df_whole_price.head()
# Out:
#   wholesale_price
# 0          $1.58
# 1          $1.58
# 2          $4.92
# 3          $4.92
# 4          $1.19

# %% [markdown]
# Online price is not in the previous divs, so inspecting the website, we found that the the wholesale price is inside a div under the class div 'color-highlight margin-bottom--5', and it is consistent across all the pages, so we can create a function that gives us access to that div initially

# %%
#access the information in the HTML to create the online price list
online_cal = soup.findAll('div',class_='color-highlight margin-bottom--5')
#wholesale_cal = soup.findAll('span', class_="")

#Display the search results and accessing the first record
#online_cal

# %%
#Creating a loop to extract the online price data within the div for page 1 only. 
#This code will be used later in the nested loop

on_price=[]
for online in online_cal:
        #Accessing the price information in the div
        online_price = online('span')
        #Creating a nested loop to extract the specific online price
        for o in online_price:
            #Accessing the sku information in the anchor tag and stripping spaces
            online_price2=online_price[1].text.strip().split('\n')[0].strip("/")
            #Appending the price information to the empty list
            on_price.append(price2)
            #Print the results
            #print(online_price2)
df_on_price = pd.DataFrame(on_price,columns = ['online_price'])
df_on_price.head()
# Out:
#   online_price
# 0       $1.82
# 1       $1.82
# 2       $1.82
# 3       $1.82
# 4       $1.82

# %% [markdown]
# #### Manufacturer

# %% [markdown]
# Manufacturer information is in the same div and under the same class as the sku information, so we will use the same code to access the first record to extract the information

# %%
#access the information in the HTML to create the manufacturers list
manufacture_cal = soup.findAll('div',class_='media-item-row')

#Display the search results and accessing the first record
manufacture_cal
#manu_2=manufacture_cal[2].text
#manu_2
# Out:
# [<div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0826359;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0826359
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">5" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc</div>,
#  <div class="media-item-row">3M PRODUCTS</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0826359_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0826359_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0826359_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0826362;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0826362
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">7" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc</div>,
#  <div class="media-item-row">3M PRODUCTS</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0826362_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0826362_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0826362_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0812730;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0812730
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">4-1/2" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc</div>,
#  <div class="media-item-row">Blackstone®</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812730_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812730_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812730_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0812730_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_2" src="https://img0.fastenal.com/productimages/supplemental/glbl_attr_img/Warning-icon_blk-ylw_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>CA Prop65</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0812777;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0812777
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">4-1/2" x 7/8" Red/Pink 36 Grit Ceramic Blackstone® Fiber Disc</div>,
#  <div class="media-item-row">Blackstone®</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812777_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812777_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812777_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0812777_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_2" src="https://img0.fastenal.com/productimages/supplemental/glbl_attr_img/Warning-icon_blk-ylw_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>CA Prop65</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0826357;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0826357
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">4-1/2" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc</div>,
#  <div class="media-item-row">CUBITRON® II</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0826357_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0826357_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0826357_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0812732;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0812732
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">4-1/2" x 7/8" Brown 60 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc</div>,
#  <div class="media-item-row">Blackstone®</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812732_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812732_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812732_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0812732_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_2" src="https://img0.fastenal.com/productimages/supplemental/glbl_attr_img/Warning-icon_blk-ylw_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>CA Prop65</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0802678;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0802678
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">TRIM KUT 36 Grit 4-1/2" Red Depressed Center AlumOxide Disc</div>,
#  <div class="media-item-row">GEMTEX ABRASIVES</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0802678_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0802678_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0802678_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0812762;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0812762
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">4-1/2" x 7/8" Blue 36 Grit Zirconia Blackstone® Fiber Sanding Disc</div>,
#  <div class="media-item-row">Blackstone®</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812762_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812762_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812762_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0812762_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_2" src="https://img0.fastenal.com/productimages/supplemental/glbl_attr_img/Warning-icon_blk-ylw_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>CA Prop65</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0200175;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0200175
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">5" x 7/8" 36 Grit Zirconia Fiber Sanding Disc</div>,
#  <div class="media-item-row">SIA ABRASIVES</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0200175_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/Fastenal_MSDS_20x20_icon.png" title="SDS"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0200175_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0200175_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0200175_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/Fastenal_MSDS_60x60_icon.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>SDS</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">(M)SDS, Material Safety Data Sheet Available
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  <li><a href="//img0.fastenal.com/productimages/supplemental/product_docs/GLIT-GEMTEX COMPANY, LTD_53297.pdf" target="_blank">Resin Fiber Disc Type A
#                                                      <i class="fa fa-external-link"></i>
#  </a></li>
#  <li><a href="//img0.fastenal.com/productimages/supplemental/product_docs/SIA ABRASIVES INDUSTRIES AG_177070.pdf" target="_blank">Abrasives Group 3: 2503, 2505, 2515, 2546, 2803, 2813, 2828, 2848, 2945, 2946, 2948, 2985, 4515, 4815, 4848, Fibre Siastar, Form Siastar, Wing Siastar 2813, 2828 Siaflap Stingray
#                                                      <i class="fa fa-external-link"></i>
#  </a></li>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_2" src="https://img0.fastenal.com/productimages/supplemental/glbl_attr_img/Warning-icon_blk-ylw_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>CA Prop65</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">WARNING: Cancer and Reproductive Harm - www.P65Warnings.ca.gov.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0812767;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0812767
#
#
#
#                                              </a>
#  </div>,
#  <div class="media-item-row">5" x 7/8" Blue 36 Grit Zirconia Blackstone® Fiber Sanding Disc</div>,
#  <div class="media-item-row">Blackstone®</div>,
#  <div class="media-item-row">
#  <span class="listview-logoit">
#  </span>
#  <div class="compliance-icon">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812767_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812767_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812767_compliance_list" data-title="Compliance" data-toggle="modal">
#  <img class="icon-item-compliance" src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  <div class="compliance__popup--wrap">
#  <div aria-labelledby="myModalLabel" class="modal fade" id="0812767_compliance_list" role="dialog" tabindex="-1">
#  <div class="modal-dialog" role="document">
#  <div class="modal-content">
#  <div class="modal-header">
#  <button aria-label="Close" class="close close--compliance--popup" data-dismiss="modal" type="button">
#  <span>×</span>
#  </button>
#  <h4 class="modal-title" id="myModalLabel">Compliance</h4>
#  </div>
#  <div class="modal-body compliance--content compliance--content--wrapper">
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_0" src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Locker</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_1" src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>Vendible Item</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  <div class="complaince-content clearfix">
#  <div class="prdcompliance__img"><img class="img-responsive js_no_Img" id="img_2" src="https://img0.fastenal.com/productimages/supplemental/glbl_attr_img/Warning-icon_blk-ylw_60x60.png"/>
#  </div>
#  <!-- compliance popup tittle-->
#  <div class="prdcompliance__details pull-left">
#  <div class="prdcompliance__header">
#  <h4>CA Prop65</h4>
#  </div>
#  <!-- compliance popup Description start-->
#  <div class="prdcompliance__desc">WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com
#
#                                  </div>
#  <div class="prdcompliance__variants">
#  <ul>
#  </ul>
#  <ul>
#  </ul>
#  </div>
#  </div>
#  <!-- compliance popup Description End-->
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                                      Fastenal Part No. (SKU)
#
#
#
#                                          </span>
#  <a href="/products/details/0812733;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                          0812733
#
#
#
#                                              </a>
# ...
#                                                  0200175
#
#
#
#                                      </a>
#  <div class="gridview__prd--desc" title='5" x 7/8" 36 Grit Zirconia Fiber Sanding Disc'>5" x 7/8" 36 Grit Zirconia Fiber Sanding Disc</div>
#  </div>,
#  <div class="media-item-row">
#  <div class="text--bold">Manufacturer</div>
#                                      SIA ABRASIVES
#                                  </div>,
#  <div class="media-item-row">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0200175_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/Fastenal_MSDS_20x20_icon.png" title="SDS"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0200175_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0200175_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  </div>,
#  <div class="media-item-row">
#  <div class="color-highlight margin-bottom--5">
#  <span class="text--bold"> Online Price:</span>
#  <span>$2.209 /
#
#          each
#
#
#  </span>
#  </div>
#  </div>,
#  <div class="media-item-row has-availability-width gridview-cartgroup-row">
#  <div class="gridview-cartgroup-wrap">
#  <span class="label-availability is-available width-flex display-long-availability" title="This item is currently available in a Fastenal Distribution Center.">
#              Available Inventory
#          </span>
#  <span class="pull-right flex-display">
#  <span class="gridview-logoit">
#  </span>
#  <span class="compliance-icon">
#  <form action="/products/add-to-cart;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990" class="gridview-form" data-complete="" data-leveltwo="" data-postback="" id="ProductAddForm" method="POST" name="ProductAddForm" novalidate="novalidate" target="">
#  <input id="sku" name="sku" type="hidden" value="0200175"/>
#  <input name="productId" type="hidden" value="0"/>
#  <input name="ajax" type="hidden" value="1"/>
#  <input name="description" type="hidden" value='5" x 7/8" 36 Grit Zirconia Fiber Sanding Disc'/>
#  <input name="templateId" type="hidden" value="-2"/>
#  <input name="agreementId" type="hidden" value=""/>
#  <input name="agreementUrl" type="hidden" value="products/agreement/;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990"/>
#  <input name="redirectToRedesign" type="hidden" value="true"/>
#  <input id="availabilityUrlV2" type="hidden" value="products/availability-v2;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990?sku="/>
#  <input name="cxml-urlencoded" type="hidden" value=""/>
#  <div class="cart-group">
#  <input class="quantity--input" data-skuqty="0200175" id="quantity" max="99999" min="1" name="quantity" type="number" value="1"/>
#  <button class="btn-default btn--highlight btn-addcart submit" onclick="productDetails.addToCart(this.form); return false;">
#  <i aria-hidden="true" class="fa fa-shopping-cart"></i>
#  </button>
#  </div>
#  </form></span>
#  </span>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                              Fastenal Part No. (SKU)
#
#
#
#                                  </span>
#  <a href="/products/details/0812767;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                  0812767
#
#
#
#                                      </a>
#  <div class="gridview__prd--desc" title='5" x 7/8" Blue 36 Grit Zirconia Blackstone&amp;reg; Fiber Sanding Disc'>5" x 7/8" Blue 36 Grit Zirconia Blackstone® Fiber Sanding Disc</div>
#  </div>,
#  <div class="media-item-row">
#  <div class="text--bold">Manufacturer</div>
#                                      Blackstone®
#                                  </div>,
#  <div class="media-item-row">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812767_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812767_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812767_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  </div>,
#  <div class="media-item-row">
#  <div class="color--blue margin-bottom--5">
#  <span class="text--bold">Wholesale:</span>
#  <span class="">$1.82 /
#
#          each
#
#
#  </span>
#  </div>
#  </div>,
#  <div class="media-item-row has-availability-width gridview-cartgroup-row">
#  <div class="gridview-cartgroup-wrap">
#  <span class="label-availability is-available width-flex display-long-availability" title="This item is currently available in a Fastenal Distribution Center.">
#              Available Inventory
#          </span>
#  <span class="pull-right flex-display">
#  <span class="gridview-logoit">
#  </span>
#  <span class="compliance-icon">
#  <form action="/products/add-to-cart;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990" class="gridview-form" data-complete="" data-leveltwo="" data-postback="" id="ProductAddForm" method="POST" name="ProductAddForm" novalidate="novalidate" target="">
#  <input id="sku" name="sku" type="hidden" value="0812767"/>
#  <input name="productId" type="hidden" value="0"/>
#  <input name="ajax" type="hidden" value="1"/>
#  <input name="description" type="hidden" value='5" x 7/8" Blue 36 Grit Zirconia Blackstone&amp;reg; Fiber Sanding Disc'/>
#  <input name="templateId" type="hidden" value="-2"/>
#  <input name="agreementId" type="hidden" value=""/>
#  <input name="agreementUrl" type="hidden" value="products/agreement/;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990"/>
#  <input name="redirectToRedesign" type="hidden" value="true"/>
#  <input id="availabilityUrlV2" type="hidden" value="products/availability-v2;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990?sku="/>
#  <input name="cxml-urlencoded" type="hidden" value=""/>
#  <div class="cart-group">
#  <input class="quantity--input" data-skuqty="0812767" id="quantity" max="99999" min="1" name="quantity" type="number" value="1"/>
#  <button class="btn-default btn--highlight btn-addcart submit" onclick="productDetails.addToCart(this.form); return false;">
#  <i aria-hidden="true" class="fa fa-shopping-cart"></i>
#  </button>
#  </div>
#  </form></span>
#  </span>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                              Fastenal Part No. (SKU)
#
#
#
#                                  </span>
#  <a href="/products/details/0812733;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                  0812733
#
#
#
#                                      </a>
#  <div class="gridview__prd--desc" title='4-1/2" x 7/8" Brown 80 Grit Aluminum Oxide Blackstone&amp;reg; Fiber Sanding Disc'>4-1/2" x 7/8" Brown 80 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc</div>
#  </div>,
#  <div class="media-item-row">
#  <div class="text--bold">Manufacturer</div>
#                                      Blackstone®
#                                  </div>,
#  <div class="media-item-row">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812733_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812733_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812733_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  </div>,
#  <div class="media-item-row">
#  <div class="color--blue margin-bottom--5">
#  <span class="text--bold">Wholesale:</span>
#  <span class="">$1.11 /
#
#          each
#
#
#  </span>
#  </div>
#  </div>,
#  <div class="media-item-row has-availability-width gridview-cartgroup-row">
#  <div class="gridview-cartgroup-wrap">
#  <span class="label-availability is-available width-flex display-long-availability" title="This item is currently available in a Fastenal Distribution Center.">
#              Available Inventory
#          </span>
#  <span class="pull-right flex-display">
#  <span class="gridview-logoit">
#  </span>
#  <span class="compliance-icon">
#  <form action="/products/add-to-cart;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990" class="gridview-form" data-complete="" data-leveltwo="" data-postback="" id="ProductAddForm" method="POST" name="ProductAddForm" novalidate="novalidate" target="">
#  <input id="sku" name="sku" type="hidden" value="0812733"/>
#  <input name="productId" type="hidden" value="0"/>
#  <input name="ajax" type="hidden" value="1"/>
#  <input name="description" type="hidden" value='4-1/2" x 7/8" Brown 80 Grit Aluminum Oxide Blackstone&amp;reg; Fiber Sanding Disc'/>
#  <input name="templateId" type="hidden" value="-2"/>
#  <input name="agreementId" type="hidden" value=""/>
#  <input name="agreementUrl" type="hidden" value="products/agreement/;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990"/>
#  <input name="redirectToRedesign" type="hidden" value="true"/>
#  <input id="availabilityUrlV2" type="hidden" value="products/availability-v2;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990?sku="/>
#  <input name="cxml-urlencoded" type="hidden" value=""/>
#  <div class="cart-group">
#  <input class="quantity--input" data-skuqty="0812733" id="quantity" max="99999" min="1" name="quantity" type="number" value="1"/>
#  <button class="btn-default btn--highlight btn-addcart submit" onclick="productDetails.addToCart(this.form); return false;">
#  <i aria-hidden="true" class="fa fa-shopping-cart"></i>
#  </button>
#  </div>
#  </form></span>
#  </span>
#  </div>
#  </div>,
#  <div class="media-item-row">
#  <span class="txtweight-medium">
#
#
#                                              Fastenal Part No. (SKU)
#
#
#
#                                  </span>
#  <a href="/products/details/0812738;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990">
#
#
#                                                  0812738
#
#
#
#                                      </a>
#  <div class="gridview__prd--desc" title='5" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone&amp;reg; Fiber Sanding Disc'>5" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc</div>
#  </div>,
#  <div class="media-item-row">
#  <div class="text--bold">Manufacturer</div>
#                                      Blackstone®
#                                  </div>,
#  <div class="media-item-row">
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812738_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/outdoor-locker-pickup_icon_20x20.png" title="Locker"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812738_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/compliance-icons/fast-5000-vendible-item-20x20.png" title="Vendible Item"/>
#  </a>
#  <a class="modal-link" data-backdrop="static" data-keyboard="false" data-target="#0812738_compliance_grid" data-title="Compliance" data-toggle="modal">
#  <img src="//www.fastenal.com/content/Images/complianceIcons/Warning-icon_blk-ylw_20x20.png" title="CA Prop65"/>
#  </a>
#  </div>,
#  <div class="media-item-row">
#  <div class="color--blue margin-bottom--5">
#  <span class="text--bold">Wholesale:</span>
#  <span class="">$1.82 /
#
#          each
#
#
#  </span>
#  </div>
#  </div>,
#  <div class="media-item-row has-availability-width gridview-cartgroup-row">
#  <div class="gridview-cartgroup-wrap">
#  <span class="label-availability is-available width-flex display-long-availability" title="This item is currently available in a Fastenal Distribution Center.">
#              Available Inventory
#          </span>
#  <span class="pull-right flex-display">
#  <span class="gridview-logoit">
#  </span>
#  <span class="compliance-icon">
#  <form action="/products/add-to-cart;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990" class="gridview-form" data-complete="" data-leveltwo="" data-postback="" id="ProductAddForm" method="POST" name="ProductAddForm" novalidate="novalidate" target="">
#  <input id="sku" name="sku" type="hidden" value="0812738"/>
#  <input name="productId" type="hidden" value="0"/>
#  <input name="ajax" type="hidden" value="1"/>
#  <input name="description" type="hidden" value='5" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone&amp;reg; Fiber Sanding Disc'/>
#  <input name="templateId" type="hidden" value="-2"/>
#  <input name="agreementId" type="hidden" value=""/>
#  <input name="agreementUrl" type="hidden" value="products/agreement/;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990"/>
#  <input name="redirectToRedesign" type="hidden" value="true"/>
#  <input id="availabilityUrlV2" type="hidden" value="products/availability-v2;jsessionid=MKZdi2lYYpF1bNbRYBYJOCdf.713728dc-d653-355a-a89c-3e45dac6e990?sku="/>
#  <input name="cxml-urlencoded" type="hidden" value=""/>
#  <div class="cart-group">
#  <input class="quantity--input" data-skuqty="0812738" id="quantity" max="99999" min="1" name="quantity" type="number" value="1"/>
#  <button class="btn-default btn--highlight btn-addcart submit" onclick="productDetails.addToCart(this.form); return false;">
#  <i aria-hidden="true" class="fa fa-shopping-cart"></i>
#  </button>
#  </div>
#  </form></span>
#  </span>
#  </div>
#  </div>]

# %% [markdown]
# Following the same process, after accessing the first record, we can now try the code in a for loop to extract all of the descriptions numbers from page 1

# %%
#Creating a loop to extract the manufacturers data within the div for page 1 only. 
#This code will be used later in the nested loop
for manu in manufacture_cal:
        #Accessing the manufacturers information in the div
        detail = manu.text.strip().split('\n')
        #Creating a nested loop to extract the manufacturer
        #for d in detail:
            #Accessing the sku information in the anchor tag and stripping spaces
            #detail2=detail.text
            #Print the results
        print(detail)
        
#sku2 = sku_list[0].text.strip().split('\n')[-1].strip()
# Out:
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0826359']
# ['5" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc']
# ['3M PRODUCTS']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0826362']
# ['7" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc']
# ['3M PRODUCTS']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0812730']
# ['4-1/2" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Blackstone®']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0812777']
# ['4-1/2" x 7/8" Red/Pink 36 Grit Ceramic Blackstone® Fiber Disc']
# ['Blackstone®']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0826357']
# ['4-1/2" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc']
# ['CUBITRON® II']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0812732']
# ['4-1/2" x 7/8" Brown 60 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Blackstone®']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0802678']
# ['TRIM KUT 36 Grit 4-1/2" Red Depressed Center AlumOxide Disc']
# ['GEMTEX ABRASIVES']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0812762']
# ['4-1/2" x 7/8" Blue 36 Grit Zirconia Blackstone® Fiber Sanding Disc']
# ['Blackstone®']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0200175']
# ['5" x 7/8" 36 Grit Zirconia Fiber Sanding Disc']
# ['SIA ABRASIVES']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'SDS', '', '', '(M)SDS, Material Safety Data Sheet Available', '                                    ', '                                ', '', '', 'Resin Fiber Disc Type A \xa0', '                                                    ', '', 'Abrasives Group 3: 2503, 2505, 2515, 2546, 2803, 2813, 2828, 2848, 2945, 2946, 2948, 2985, 4515, 4815, 4848, Fibre Siastar, Form Siastar, Wing Siastar 2813, 2828 Siaflap Stingray \xa0', '                                                    ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: Cancer and Reproductive Harm - www.P65Warnings.ca.gov.']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0812767']
# ['5" x 7/8" Blue 36 Grit Zirconia Blackstone® Fiber Sanding Disc']
# ['Blackstone®']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0812733']
# ['4-1/2" x 7/8" Brown 80 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Blackstone®']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com']
# ['Fastenal Part No. (SKU)', '                                                ', '                                                ', '                                            ', '                                        ', '', '                                                ', '                                                    ', '                                                        0812738']
# ['5" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Blackstone®']
# ['×', '', 'Compliance', '', '', '', '', '', '', '', '', 'Locker', '', '', 'This Product has been approved for Locker Pickup service, but final compliance will be subject to weight and size limits for the quantity ordered', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Vendible Item', '', '', 'The item is tested and deemed vendible in the following vending machines as the EA and/or Package Quantity.', '                                    ', '                                ', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CA Prop65', '', '', 'WARNING: This product can expose you to chemicals including formaldehyde, which is known to the State of California to cause cancer or birth defects or other reproductive harm.  For more information go to www.P65Warnings.ca.gov/furntiture.com']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0826359', '                                            ', '                                            ', '                                        ', '                                    ', '5" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc']
# ['Manufacturer', '                                    3M PRODUCTS']
# ['']
# ['Online Price:', '$5.7683\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0826362', '                                            ', '                                            ', '                                        ', '                                    ', '7" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc']
# ['Manufacturer', '                                    3M PRODUCTS']
# ['']
# ['Online Price:', '$6.9275\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0812730', '                                            ', '                                            ', '                                        ', '                                    ', '4-1/2" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Manufacturer', '                                    Blackstone®']
# ['']
# ['Wholesale:', '$1.58\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0812777', '                                            ', '                                            ', '                                        ', '                                    ', '4-1/2" x 7/8" Red/Pink 36 Grit Ceramic Blackstone® Fiber Disc']
# ['Manufacturer', '                                    Blackstone®']
# ['']
# ['Wholesale:', '$4.92\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0826357', '                                            ', '                                            ', '                                        ', '                                    ', '4-1/2" x 7/8" 36+ 982C 3M CUBITRON II Fiber Disc']
# ['Manufacturer', '                                    CUBITRON® II']
# ['']
# ['Online Price:', '$5.4383\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0812732', '                                            ', '                                            ', '                                        ', '                                    ', '4-1/2" x 7/8" Brown 60 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Manufacturer', '                                    Blackstone®']
# ['']
# ['Wholesale:', '$1.19\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0802678', '                                            ', '                                            ', '                                        ', '                                    ', 'TRIM KUT 36 Grit 4-1/2" Red Depressed Center AlumOxide Disc']
# ['Manufacturer', '                                    GEMTEX ABRASIVES']
# ['']
# ['Online Price:', '$253.26\xa0/', '    ', '    ', '        case of 100', '    ', '', '', '', 'Unit Price:', '', '                            ', '                                ', '                                    $2.5326\xa0/', 'each']
# ['Ships from Manuf.']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0812762', '                                            ', '                                            ', '                                        ', '                                    ', '4-1/2" x 7/8" Blue 36 Grit Zirconia Blackstone® Fiber Sanding Disc']
# ['Manufacturer', '                                    Blackstone®']
# ['']
# ['Wholesale:', '$1.99\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0200175', '                                            ', '                                            ', '                                        ', '                                    ', '5" x 7/8" 36 Grit Zirconia Fiber Sanding Disc']
# ['Manufacturer', '                                    SIA ABRASIVES']
# ['']
# ['Online Price:', '$2.209\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0812767', '                                            ', '                                            ', '                                        ', '                                    ', '5" x 7/8" Blue 36 Grit Zirconia Blackstone® Fiber Sanding Disc']
# ['Manufacturer', '                                    Blackstone®']
# ['']
# ['Wholesale:', '$1.82\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0812733', '                                            ', '                                            ', '                                        ', '                                    ', '4-1/2" x 7/8" Brown 80 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Manufacturer', '                                    Blackstone®']
# ['']
# ['Wholesale:', '$1.11\xa0/', '    ', '        each']
# ['Available Inventory']
# ['Fastenal Part No. (SKU)', '                                        ', '                                        ', '                                    ', '                                ', '', '                                        ', '                                            ', '                                                0812738', '                                            ', '                                            ', '                                        ', '                                    ', '5" x 7/8" Brown 36 Grit Aluminum Oxide Blackstone® Fiber Sanding Disc']
# ['Manufacturer', '                                    Blackstone®']
# ['']
# ['Wholesale:', '$1.82\xa0/', '    ', '        each']
# ['Available Inventory']

# %% [markdown]
# ### Master loop

# %% [markdown]
# Once all the searches have been created, we consolidate everything into a master loop that will ultimately scrape and generate all the combined results at once

# %%
#Creating all the empty lists that will hold all the search results extracted from the for loop
#SKU information
sku=[]
#Product description
description= []
#Price
wholesale_price=[]
#Manufacturer
manufacturer=[]

#Initiating the for loop and setting the page range
for i in range(2,5):
    
    #Opening the browser
    html = browser.html
    #Making the soup
    soup = BeautifulSoup(html, 'html.parser')
    #Accessing the divs that contain the data we are looking for
    grid_view = soup.findAll('div',class_='gridview__prd--desc')
    
    #Creating a nested loop to extract the data within the divs
    for view in grid_view:
        #Accessing the sku information in the div
        sku_list=sku_list[0].text.strip().split('\n')[-1].strip()
        #Accessing the description information in the div
        description_list = view.text
        #Accessing the price information in the div
        wholesale_price_list=
        #Accessing the manufacturer information in the div
        manufacturer_list=
        
        #Appending the sku information to the empty list
        sku.append(sku_list)
        #Appending the description information to the empty list
        description.append(description_list)
        #Appending the price information to the empty list
        wholesale_price.append(wholesale_price_list)
        #Appending the manufacturer information to the empty list
        manufacturer.append(manufacturer_list)
        
        #Setting a try function to iterate over all the pages
        try:
            #Initial url
            link = f"/product/abrasives/coated-and-non-woven-abrasives/fiber-and-sanding-discs/609478?categoryId=609478&level=3&isExpanded=true&productFamilyId=26373&page={i}&pageSize=12&exactSkuMatchLevel=useData&view=1"
            #Printing the url found
            print(link)
            #Set a click by href action to go to the next page
            browser.click_link_by_href(link)
            #Print the page number
            print(i)

        #Setting an except function to stop when there is not other url to click on
        except ElementDoesNotExist:
            #Print an exit message
            print("Scraping Complete")
            #Breaking the loop when there is no other url to click on
            break
