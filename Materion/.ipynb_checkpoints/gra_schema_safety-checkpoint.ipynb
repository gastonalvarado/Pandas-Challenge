# %% [markdown]
# # Gra - Category Chart

# %% [markdown]
# Code developed to build the category chart for the Gra website. The objective is to collect all of the urls for each one of the product categories and subcategories and their names so we can build the hierarchy and also use the urls for the data scraping of all of the part numbers

# %% [markdown]
# ## Import all dependencies and start selenium

# %% [markdown]
# We are using selenium and BeautifulSoup for the scraping process

# %%
#Finding the location of chromedriver.exe
#https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver

# %%
# Import your newly installed selenium package
from selenium import webdriver
from splinter import Browser
from selenium.webdriver.common.keys import Keys
import time
time.sleep(3)
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import pandas as pd

# Now create an 'instance' of your driver
WebDriver = {'executable_path': 'chromedriver'}
# A new Chrome (or other browser) window should open up
browser = Browser('chrome', **WebDriver, headless=False)
# Defining width and height of the browser
browser.driver.set_window_size(1750, 1250)

# %% [markdown]
# # Initialize searches

# %% [markdown]
# ## All Safety Categories - Level 3

# %%
#For Windows users - Opening the target url
url ='https://www.grainger.com/category/safety'
browser.visit(url)

#activating soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

#Extract all categories from the span tag
spans = soup.findAll('a', class_='route category-link') 
#List comprehension to extract the initial url from the span class
all_safety_category=[span['href'] for span in spans]
#List comprehension to build the end url
all_safety_category_links=[f'https://www.grainger.com/{link}' for link in all_safety_category]
all_safety_category_links

# %% [markdown]
# ## All Safety Categories - Level 4

# %%
#Create the empty list that will hold the urls
test_urls=[]
#For loop to iterate through all urls
for x in all_safety_category_links:
    #Opening the browser
    browser.visit(x)
    #setting a sleep time between iterations
    time.sleep(3)
    #activating soup
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    #finding the tags that contain the urls
    spans = soup.findAll('a', class_='route category-link')
    #Nested loop to iterate through the specific tags in each url
    for spa in spans:
        #setting an error handling method
        try: 
            #extracting the url of each category on each url
            all_safety_category=spa['href']
        #identifying the error
        except IndexError:
            #printing error message
            print('#-----------')
            print ('This is the end url')
            
        #appending to the empty list all urls found
        test_urls.append(all_safety_category)
#displaying the results
test_urls
#Only missing URL is https://www.grainger.com//category/safety/respiratory

# %%
#List comprehension to build the end url
all_urls_level_4=[f'https://www.grainger.com/{link}' for link in test_urls]
all_urls_level_4

# %%
changes=[]
for i in all_safety_category_links:
    change=i.rpartition('/')[2]
    changes.append(change)
            
changes

# %%
#for text in all_urls_level_4:
    #for safety in all_safety_category_links:
        #if safety not in text:
            #print(text)

# %%
#short_links=[]
#for i in all_urls_level_4:
        #if i not in (changes):
            #short_links.append(i)
            
#short_links

# %% [markdown]
# ## All Safety Categories - Level 5

# %%
#Create the empty list that will hold the urls
urls_level_5=[]
#For loop to iterate through all urls
for x in all_urls_level_4:
    #Opening the browser
    browser.visit(x)
    #setting a sleep time between iterations
    time.sleep(3)
    #activating soup
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    #finding the tags that contain the urls
    spans = soup.findAll('a', class_='route category-link')
    #Nested loop to iterate through the specific tags in each url
    for spa in spans:
        #setting an error handling method
        try: 
            #extracting the url of each category on each url
            all_safety_category=spa['href']
        #identifying the error
        except IndexError:
            #printing error message
            print('#-----------')
            print ('This is the end url')
            
        #appending to the empty list all urls found
        urls_level_5.append(all_safety_category)
#displaying the results
urls_level_5

# %%
#List comprehension to build the end url
all_urls_level_5=[f'https://www.grainger.com/{link}' for link in urls_level_5]
all_urls_level_5

# %%
df = pd.DataFrame(all_urls_level_4, columns=["colummn"])
df.to_csv('all_urls_level_4.csv', index=False)

# %%
df = pd.DataFrame(all_urls_level_5, columns=["colummn"])
df.to_csv('all_urls_level_5.csv', index=False)

# %% [markdown]
# ## All items Level 4

# %% [markdown]
# Need to complement with all urls that are not moving from level to level, and with all the items that are under table view type

# %%
import csv
skus_level_4 = []
with open('all_urls_level_4.csv') as file:
    for line in csv.reader(file,delimiter='\t'):
        skus_level_4.append((line[0]))

skus_level_4
# Out:
# ['https://www.grainger.com//category/safety/arc-flash-protection/arc-protection-blankets',
#  'https://www.grainger.com//category/safety/arc-flash-protection/electrical-safety-accessories',
#  'https://www.grainger.com//category/safety/arc-flash-protection/electrical-sticks-and-rescue-hooks',
#  'https://www.grainger.com//category/safety/arc-flash-protection/grounding-equipment',
#  'https://www.grainger.com//category/safety/arc-flash-protection/insulating-line-hoses',
#  'https://www.grainger.com//category/safety/arc-flash-protection/shock-protection-blankets',
#  'https://www.grainger.com//category/safety/asbestos-abatement/asbestos-disposal-bags',
#  'https://www.grainger.com//category/safety/asbestos-abatement/asbestos-encapsulants',
#  'https://www.grainger.com//category/safety/confined-space-equipment/air-powered-confined-space-fans-and-blowers',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-carts',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-entry-accessories',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-entry-systems',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-entry-winches',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-fan-and-blower-accessories',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-hoist-frames',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-hoist-lower-mast-extensions',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-hoist-mounts',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-hoist-portable-bases',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-hoist-upper-masts',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-hoist-vehicle-hitch-mounts',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-pole-hoists',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-pulleys',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-tripods',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-ventilation-duct-accessories',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-ventilation-ducting',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-venturi-blowers',
#  'https://www.grainger.com//category/safety/confined-space-equipment/confined-space-winch-mounting-brackets',
#  'https://www.grainger.com//category/safety/confined-space-equipment/electric-confined-space-fans-and-blowers',
#  'https://www.grainger.com//category/safety/confined-space-equipment/fuel-powered-confined-space-fans-and-blowers',
#  'https://www.grainger.com//category/safety/confined-space-equipment/manhole-cover-accessories',
#  'https://www.grainger.com//category/safety/confined-space-equipment/manhole-cover-lifters',
#  'https://www.grainger.com//category/safety/confined-space-equipment/manhole-guard-rail-winches',
#  'https://www.grainger.com//category/safety/confined-space-equipment/manhole-guard-rails',
#  'https://www.grainger.com//category/safety/confined-space-equipment/manhole-shelters-and-umbrellas',
#  'https://www.grainger.com//category/safety/confined-space-equipment/manhole-smoke-blowers',
#  'https://www.grainger.com//category/safety/confined-space-equipment/saddle-vents',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/chemical-resistant-and-disposable-aprons',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/chemical-resistant-and-disposable-clothing-accessories',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/chemical-resistant-and-disposable-coveralls',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/chemical-resistant-and-disposable-hoods',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/chemical-resistant-and-disposable-sleeves',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/disposable-barrier-gowns',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/disposable-lab-coats-smocks-and-jackets',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/disposable-pants',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/disposable-shirts',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/encapsulated-chemical-suits',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/hairnets-bouffants-and-beard-nets',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/shoe-cover-and-hairnet-dispensers',
#  'https://www.grainger.com//category/safety/disposable-and-chemical-resistant-clothing/shoe-and-boot-covers',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/aspirators-and-suction-equipment',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/automated-cpr-device-accessories',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/automated-cpr-devices',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/backboard-and-stretcher-accessories',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/backboards',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/bariatric-boards',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/bulb-syringes-and-aspirators',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/cpr-mask-kits',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/cervical-collars',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/defibrillator-accessories',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/defibrillator-storage-cabinets',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/defibrillators',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/ecg-electrodes',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/emt-tools-and-tool-sets',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/emt-trauma-kits',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/emergency-blankets',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/emergency-personal-comfort-kits',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/first-aid-cot-accessories',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/first-aid-cots',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/head-immobilizers',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/intubation-supplies',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/patient-transfer',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/splinter-and-suture-removal-kits',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/splints',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/stretcher-pads',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/stretchers',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/suction-catheters',
#  'https://www.grainger.com//category/safety/emt-and-rescue-supplies/suction-tubing',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/combination-eye-wash-stations',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/drench-hoses',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/drench-showers',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/emergency-eye-wash-stations',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/emergency-eye-wash-and-shower-accessories',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/eye-wash-heating-jackets',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/eye-wash-solutions-and-preservatives',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/eye-wash-and-shower-thermal-protection-valves',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/personal-eye-wash-bottles',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/personal-eye-wash-stations',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/plumbed-emergency-eye-wash-and-shower-water-heaters',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/pressurized-portable-eye-wash-stations',
#  'https://www.grainger.com//category/safety/emergency-eye-wash-and-shower-equipment/self-contained-eye-wash-stations',
#  'https://www.grainger.com//category/safety/emergency-preparedness/body-bags-and-coffins',
#  'https://www.grainger.com//category/safety/emergency-preparedness/custom-ppe-kits',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-kits',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-accessories',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-decks-and-elevation-grids',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-detergent-injectors',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-privacy-screens-and-shelters',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-pumps',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-rinsing-wands-and-shower-heads',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-supply-hoses',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-water-collection',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-shower-water-heaters',
#  'https://www.grainger.com//category/safety/emergency-preparedness/decontamination-showers',
#  'https://www.grainger.com//category/safety/emergency-preparedness/disaster-survival-kits',
#  'https://www.grainger.com//category/safety/emergency-preparedness/earthquake-safety-devices',
#  'https://www.grainger.com//category/safety/emergency-preparedness/emergency-blackout-monitors',
#  'https://www.grainger.com//category/safety/emergency-preparedness/emergency-communication-systems',
#  'https://www.grainger.com//category/safety/emergency-preparedness/emergency-lightsticks-and-accessories',
#  'https://www.grainger.com//category/safety/emergency-preparedness/emergency-response-cots-and-beds',
#  'https://www.grainger.com//category/safety/emergency-preparedness/emergency-response-ppe-kits',
#  'https://www.grainger.com//category/safety/emergency-preparedness/emergency-shelter-heaters-and-air-conditioners',
#  'https://www.grainger.com//category/safety/emergency-preparedness/emergency-water-and-food-rations',
#  'https://www.grainger.com//category/safety/emergency-preparedness/field-desks',
#  'https://www.grainger.com//category/safety/emergency-preparedness/flood-barrier-systems',
#  'https://www.grainger.com//category/safety/emergency-preparedness/hydraulic-rescue-tool-accessories',
#  'https://www.grainger.com//category/safety/emergency-preparedness/incident-command-and-triage-supplies',
#  'https://www.grainger.com//category/safety/emergency-preparedness/negative-air-machine-accessories',
#  'https://www.grainger.com//category/safety/emergency-preparedness/negative-air-machines',
#  'https://www.grainger.com//category/safety/emergency-preparedness/off-grid-energy-equipment-and-accessories',
#  'https://www.grainger.com//category/safety/emergency-preparedness/portable-water-storage',
#  'https://www.grainger.com//category/safety/emergency-preparedness/rehab-cooling-chairs',
#  'https://www.grainger.com//category/safety/emergency-preparedness/rescue-shoring-tool-accessories',
#  'https://www.grainger.com//category/safety/emergency-preparedness/sand-bags',
#  'https://www.grainger.com//category/safety/emergency-preparedness/storm-shelters',
#  'https://www.grainger.com//category/safety/emergency-preparedness/temporary-emergency-shelters',
#  'https://www.grainger.com//category/safety/emergency-preparedness/temporary-environmental-containment-unit-accessories',
#  'https://www.grainger.com//category/safety/emergency-preparedness/temporary-environmental-containment-units',
#  'https://www.grainger.com//category/safety/emergency-preparedness/whistles',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/arm-slings',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/first-aid-tweezers-and-forceps',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/medical-basins',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/medical-equipment-bags-and-cases',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/medical-scissors-and-shears',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/medical-supplies-containers',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/medical-swabs-and-applicators',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/medical-thermometers',
#  'https://www.grainger.com//category/safety/emergency-and-exam-room-supplies/tongue-depressors',
#  'https://www.grainger.com//category/safety/ergonomics/back-supports',
#  'https://www.grainger.com//category/safety/ergonomics/elbow-knee-and-ankle-supports',
#  'https://www.grainger.com//category/safety/ergonomics/kneeling-pads',
#  'https://www.grainger.com//category/safety/ergonomics/moldable-hand-grips',
#  'https://www.grainger.com//category/safety/ergonomics/protective-elbow-and-knee-pads',
#  'https://www.grainger.com//category/safety/ergonomics/wrist-supports-and-wraps',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/blood-draw-chairs',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/call-for-assistance-devices',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/exam-room-equipment',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/exam-room-flags',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/healthcare-dispenser-accessories',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/healthcare-dispensers',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/mattress-repair-kits',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/over-the-bed-tables',
#  'https://www.grainger.com//category/safety/exam-room-furnishings/privacy-screens',
#  'https://www.grainger.com//category/safety/eye-protection-and-accessories/eye-protection-accessories',
#  'https://www.grainger.com//category/safety/eye-protection-and-accessories/laser-eyewear-and-goggles',
#  'https://www.grainger.com//category/safety/eye-protection-and-accessories/prescription-insert-holders',
#  'https://www.grainger.com//category/safety/eye-protection-and-accessories/protective-goggles',
#  'https://www.grainger.com//category/safety/eye-protection-and-accessories/reader-eyewear',
#  'https://www.grainger.com//category/safety/eye-protection-and-accessories/replacement-eyewear-lenses',
#  'https://www.grainger.com//category/safety/eye-protection-and-accessories/safety-glasses',
#  'https://www.grainger.com//category/safety/face-protection/faceshield-accessories',
#  'https://www.grainger.com//category/safety/face-protection/faceshield-assemblies',
#  'https://www.grainger.com//category/safety/face-protection/faceshield-headgear',
#  'https://www.grainger.com//category/safety/face-protection/faceshield-replacement-visors',
#  'https://www.grainger.com//category/safety/face-protection/splash-shield-starter-kits',
#  'https://www.grainger.com//category/safety/fall-protection/beam-and-steel-anchors',
#  'https://www.grainger.com//category/safety/fall-protection/body-belts',
#  'https://www.grainger.com//category/safety/fall-protection/carabiners',
#  'https://www.grainger.com//category/safety/fall-protection/concrete-anchors',
#  'https://www.grainger.com//category/safety/fall-protection/fall-arrest-post-davit-arms',
#  'https://www.grainger.com//category/safety/fall-protection/fall-arrest-posts-and-extensions',
#  'https://www.grainger.com//category/safety/fall-protection/fall-protection-kits',
#  'https://www.grainger.com//category/safety/fall-protection/fall-rescue-accessories',
#  'https://www.grainger.com//category/safety/fall-protection/fall-rescue-devices',
#  'https://www.grainger.com//category/safety/fall-protection/guardrails',
#  'https://www.grainger.com//category/safety/fall-protection/harness-accessories',
#  'https://www.grainger.com//category/safety/fall-protection/harnesses',
#  'https://www.grainger.com//category/safety/fall-protection/horizontal-and-vertical-lifelines',
#  'https://www.grainger.com//category/safety/fall-protection/lifeline-accessories',
#  'https://www.grainger.com//category/safety/fall-protection/positioning-and-restraint-lanyards',
#  'https://www.grainger.com//category/safety/fall-protection/rescue-harnesses',
#  'https://www.grainger.com//category/safety/fall-protection/roof-hatch-railing-systems',
#  'https://www.grainger.com//category/safety/fall-protection/roofing-anchors',
#  'https://www.grainger.com//category/safety/fall-protection/rope-grabs',
#  'https://www.grainger.com//category/safety/fall-protection/safety-netting-systems',
#  'https://www.grainger.com//category/safety/fall-protection/self-retracting-lifelines',
#  'https://www.grainger.com//category/safety/fall-protection/shock-absorbing-lanyards',
#  'https://www.grainger.com//category/safety/fall-protection/skylight-guards',
#  'https://www.grainger.com//category/safety/fall-protection/specialty-anchors',
#  'https://www.grainger.com//category/safety/fall-protection/vacuum-anchors',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/fire-hoods',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/fire-and-rescue-boots',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/fire-and-rescue-helmets',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/turnout-gear-dryers',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/turnout-gear-storage-rack-accessories',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/turnout-gear-storage-racks',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/turnout-and-extrication-coveralls',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/turnout-and-extrication-jackets-and-coats',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/turnout-and-extrication-pants',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/wildland-fire-fighting-jackets-and-coats',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/wildland-fire-fighting-pants',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/wildland-gear-belts',
#  'https://www.grainger.com//category/safety/fire-fighting-clothing-and-accessories/wildland-gear-packs-and-bags',
#  'https://www.grainger.com//category/safety/fire-protection/dry-hydrants',
#  'https://www.grainger.com//category/safety/fire-protection/escape-ladders',
#  'https://www.grainger.com//category/safety/fire-protection/fire-barrier-products',
#  'https://www.grainger.com//category/safety/fire-protection/fire-blankets',
#  'https://www.grainger.com//category/safety/fire-protection/fire-extinguisher-alarms',
#  'https://www.grainger.com//category/safety/fire-protection/fire-extinguisher-brackets',
#  'https://www.grainger.com//category/safety/fire-protection/fire-extinguisher-cabinets',
#  'https://www.grainger.com//category/safety/fire-protection/fire-extinguisher-carts-and-stands',
#  'https://www.grainger.com//category/safety/fire-protection/fire-extinguisher-covers',
#  'https://www.grainger.com//category/safety/fire-protection/fire-extinguishers',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hose-reels-and-storage-racks',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hose-washing-machines',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hose-and-fire-extinguisher-accessories',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hose-and-hydrant-adapters',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hose-and-hydrant-valve-accessories',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hose-and-hydrant-valves',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hoses',
#  'https://www.grainger.com//category/safety/fire-protection/fire-hydrant-relief-valves',
#  'https://www.grainger.com//category/safety/fire-protection/fire-probing-tools',
#  'https://www.grainger.com//category/safety/fire-protection/fire-resistant-treatments',
#  'https://www.grainger.com//category/safety/fire-protection/firefighting-foams',
#  'https://www.grainger.com//category/safety/fire-protection/forest-fire-shelters',
#  'https://www.grainger.com//category/safety/fire-protection/industrial-and-fire-hose-nozzles',
#  'https://www.grainger.com//category/safety/fire-protection/monitors',
#  'https://www.grainger.com//category/safety/fire-protection/smoke-machine-accessories',
#  'https://www.grainger.com//category/safety/fire-protection/spanner-and-hydrant-wrenches',
#  'https://www.grainger.com//category/safety/fire-protection/wildland-fire-hand-tools',
#  'https://www.grainger.com//category/safety/fire-protection/wildland-fire-pumps',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/adhesive-bandages',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/cast-and-bandage-protectors',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/empty-first-aid-kit-accessories',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/first-aid-gauze-pads-and-wraps',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/first-aid-ice-packs-and-thermal-wraps',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/first-aid-tapes',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/general-first-aid-kits',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/medicinals-non-prescription-medication',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/medicine-vending-machine-accessories',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/medicine-vending-machines',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/pill-cutters-and-organizers',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/spray-and-liquid-bandages',
#  'https://www.grainger.com//category/safety/first-aid-and-wound-care/topical-ointments-creams-and-antiseptics',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/aluminized-aprons',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/aluminized-chaps-leggings-and-cover-boots',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/aluminized-hoods-gloves-and-sleeves',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/aluminized-jackets-and-coats',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/aluminized-pants',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/arc-flash-clothing-accessories',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/arc-flash-clothing-kits',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/arc-flash-hoods',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-aprons',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-rain-suits',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-coveralls',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-hats-helmets-and-headwear',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-jackets-and-coats',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-pants-and-overalls',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-rain-jackets-and-coats',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-rain-pants-and-overalls',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-shirts',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-arc-flash-undergarments',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-resistant-and-welding-sleeves',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-retardant-treated-cotton-coveralls',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-retardant-treated-cotton-hats',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-retardant-treated-cotton-jackets-and-coats',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-retardant-treated-cotton-pants-and-overalls',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/flame-retardant-treated-cotton-sleeves',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/welding-aprons',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/welding-chaps-and-spats',
#  'https://www.grainger.com//category/safety/flame-resistant-and-arc-flash-clothing/welding-jackets-and-coats',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/anti-fatigue-soles',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/boot-brushes',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/boot-dryers',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/boot-liners',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/boot-and-shoe-laces',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/chest-wader-suspenders-and-belts',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/chest-waders',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/dielectric-overboots-and-overshoes',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/fire-and-rescue-boots',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/floor-coating-spiked-shoes',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/foot-and-leg-guards',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/footwear-accessories',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/footwear-scrubbers-and-sanitizers',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/footwear-traction-devices',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/hip-boots-and-waders',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/insoles',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/military-and-tactical-boots',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/overboots-and-overshoes',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/plain-toe-work-boots-and-shoes',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/rubber-boots',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/shoe-and-boot-covers',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/socks',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/steel-toe-work-boots-and-shoes',
#  'https://www.grainger.com//category/safety/footwear-and-footwear-accessories/winter-boots',
#  'https://www.grainger.com//category/safety/gas-detection/automated-gas-detector-test-systems',
#  'https://www.grainger.com//category/safety/gas-detection/calibration-adapters',
#  'https://www.grainger.com//category/safety/gas-detection/calibration-gas',
#  'https://www.grainger.com//category/safety/gas-detection/calibration-kits-and-stations',
#  'https://www.grainger.com//category/safety/gas-detection/detector-tube-pumps-and-kits',
#  'https://www.grainger.com//category/safety/gas-detection/detector-tube-and-pump-kits',
#  'https://www.grainger.com//category/safety/gas-detection/devalving-tools',
#  'https://www.grainger.com//category/safety/gas-detection/fixed-gas-detector-controllers',
#  'https://www.grainger.com//category/safety/gas-detection/fixed-gas-detectors',
#  'https://www.grainger.com//category/safety/gas-detection/gas-cylinder-regulators',
#  'https://www.grainger.com//category/safety/gas-detection/gas-detection-accessories',
#  'https://www.grainger.com//category/safety/gas-detection/gas-detection-control-panels',
#  'https://www.grainger.com//category/safety/gas-detection/gas-detection-tube-and-pump-accessories',
#  'https://www.grainger.com//category/safety/gas-detection/gas-detector-battery-chargers',
#  'https://www.grainger.com//category/safety/gas-detection/gas-detector-cases-and-boots',
#  'https://www.grainger.com//category/safety/gas-detection/gas-detector-interface-hardware',
#  'https://www.grainger.com//category/safety/gas-detection/multi-gas-detectors',
#  'https://www.grainger.com//category/safety/gas-detection/protector-cases',
#  'https://www.grainger.com//category/safety/gas-detection/replacement-batteries',
#  'https://www.grainger.com//category/safety/gas-detection/replacement-sensors',
#  'https://www.grainger.com//category/safety/gas-detection/sample-draw-pumps',
#  'https://www.grainger.com//category/safety/gas-detection/single-gas-detection-tubes',
#  'https://www.grainger.com//category/safety/gas-detection/single-gas-detectors',
#  'https://www.grainger.com//category/safety/gas-detection/smoke-generating-tubes',
#  'https://www.grainger.com//category/safety/gas-detection/smoke-generation-kits',
#  'https://www.grainger.com//category/safety/gas-detection/volatile-organic-compound-detectors',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/antistatic-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/arc-flash-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/chemical-resistant-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/coated-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/cold-condition-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/cryogenic-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/cut-resistant-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/disposable-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/electrical-glove-accessories',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/electrical-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/extrication-and-rescue-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/finger-cots',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/firefighter-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/flame-retardant-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/general-purpose-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/glove-box-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/glove-dispensers',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/glove-holder-clips',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/hand-and-finger-guards',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/heat-resistant-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/heated-gloves-and-hand-warmers',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/impact-resistant-and-anti-vibration-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/inspection-gloves-and-glove-liners',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/leather-work-and-drivers-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/mechanics-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/military-police-and-tactical-gloves',
#  'https://www.grainger.com//category/safety/gloves-and-hand-protection/welding-gloves',
#  'https://www.grainger.com//category/safety/head-protection/bump-caps',
#  'https://www.grainger.com//category/safety/head-protection/hard-hats-and-helmets',
#  'https://www.grainger.com//category/safety/head-protection/head-protection-accessories',
#  'https://www.grainger.com//category/safety/head-protection/head-protection-combination-kits',
#  'https://www.grainger.com//category/safety/head-protection/suspensions-for-hard-hats-and-helmets',
#  'https://www.grainger.com//category/safety/head-protection/welding-helmets',
#  'https://www.grainger.com//category/safety/hearing-protection/ear-plugs',
#  'https://www.grainger.com//category/safety/hearing-protection/ear-plugs-metal-detectable',
#  'https://www.grainger.com//category/safety/hearing-protection/earmuffs',
#  'https://www.grainger.com//category/safety/hearing-protection/earplug-dispensers-and-refills',
#  'https://www.grainger.com//category/safety/hearing-protection/headsets-for-communication',
#  'https://www.grainger.com//category/safety/hearing-protection/sound-level-meters',
#  'https://www.grainger.com//category/safety/iv-supplies/flow-meters',
#  'https://www.grainger.com//category/safety/iv-supplies/iv-accessories',
#  'https://www.grainger.com//category/safety/iv-supplies/iv-pole-accessories',
#  'https://www.grainger.com//category/safety/iv-supplies/iv-poles',
#  'https://www.grainger.com//category/safety/iv-supplies/iv-sets',
#  'https://www.grainger.com//category/safety/iv-supplies/sharps-container-accessories',
#  'https://www.grainger.com//category/safety/iv-supplies/sharps-containers',
#  'https://www.grainger.com//category/safety/identification-products/5s-red-tag-stations',
#  'https://www.grainger.com//category/safety/identification-products/ammonia-refrigeration-pipe-markers',
#  'https://www.grainger.com//category/safety/identification-products/encoded-microdots',
#  'https://www.grainger.com//category/safety/identification-products/hand-stamp-sets',
#  'https://www.grainger.com//category/safety/identification-products/identification-tags',
#  'https://www.grainger.com//category/safety/identification-products/label-maker-ink-cartridges',
#  'https://www.grainger.com//category/safety/identification-products/label-makers-printers-and-supplies',
#  'https://www.grainger.com//category/safety/identification-products/labels',
#  'https://www.grainger.com//category/safety/identification-products/labor-law-posters',
#  'https://www.grainger.com//category/safety/identification-products/letters-and-numbers',
#  'https://www.grainger.com//category/safety/identification-products/pipe-markers',
#  'https://www.grainger.com//category/safety/identification-products/pipe-marking-arrows-and-banding-tape',
#  'https://www.grainger.com//category/safety/identification-products/right-to-understand-know-placards-and-signs',
#  'https://www.grainger.com//category/safety/identification-products/right-to-understand-know-stations-and-binders',
#  'https://www.grainger.com//category/safety/identification-products/right-to-understand-know-tags',
#  'https://www.grainger.com//category/safety/identification-products/safety-banners-and-posters',
#  'https://www.grainger.com//category/safety/identification-products/shadow-boards',
#  'https://www.grainger.com//category/safety/identification-products/software-and-sign-making-kits',
#  'https://www.grainger.com//category/safety/identification-products/stencils-and-stencil-sets',
#  'https://www.grainger.com//category/safety/identification-products/tag-accessories',
#  'https://www.grainger.com//category/safety/identification-products/utility-marker-posts',
#  'https://www.grainger.com//category/safety/identification-products/vehicle-placards-and-placard-holders',
#  'https://www.grainger.com//category/safety/identification-products/worker-emergency-identification',
#  'https://www.grainger.com//category/safety/lockout-tagout/cable-lockouts',
#  'https://www.grainger.com//category/safety/lockout-tagout/electrical-lockouts',
#  'https://www.grainger.com//category/safety/lockout-tagout/flange-lockout-devices',
#  'https://www.grainger.com//category/safety/lockout-tagout/gas-cylinder-lockouts',
#  'https://www.grainger.com//category/safety/lockout-tagout/group-lockout-boxes',
#  'https://www.grainger.com//category/safety/lockout-tagout/ladder-lockout-devices',
#  'https://www.grainger.com//category/safety/lockout-tagout/locking-confined-space-covers',
#  'https://www.grainger.com//category/safety/lockout-tagout/lockout-hasps',
#  'https://www.grainger.com//category/safety/lockout-tagout/lockout-padlocks',
#  'https://www.grainger.com//category/safety/lockout-tagout/lockout-stations-and-kits',
#  'https://www.grainger.com//category/safety/lockout-tagout/lockout-tags',
#  'https://www.grainger.com//category/safety/lockout-tagout/pneumatic-lockouts',
#  'https://www.grainger.com//category/safety/lockout-tagout/steering-wheel-lockouts',
#  'https://www.grainger.com//category/safety/lockout-tagout/valve-lockout-devices',
#  'https://www.grainger.com//category/safety/matting/antifatigue-mats',
#  'https://www.grainger.com//category/safety/matting/chair-mats',
#  'https://www.grainger.com//category/safety/matting/cleanroom-tacky-mats-and-bases',
#  'https://www.grainger.com//category/safety/matting/drainage-mats',
#  'https://www.grainger.com//category/safety/matting/esd-mats',
#  'https://www.grainger.com//category/safety/matting/entrance-mats',
#  'https://www.grainger.com//category/safety/matting/floor-mats',
#  'https://www.grainger.com//category/safety/matting/ground-protection-matting',
#  'https://www.grainger.com//category/safety/matting/interlocking-mats-and-edging',
#  'https://www.grainger.com//category/safety/matting/metal-deck-antislip-matting',
#  'https://www.grainger.com//category/safety/matting/specialty-mats',
#  'https://www.grainger.com//category/safety/matting/stair-tread-covers-and-nosings',
#  'https://www.grainger.com//category/safety/matting/switchboard-mats',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/blood-glucose-monitoring',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/blood-pressure-monitors',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/ent-diagnostic-instruments',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/fall-monitoring-systems',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/fitness-measuring-devices',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/medical-oxygen-sensors',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/oxygen-analyzer-accessories',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/oxygen-and-nitrogen-analyzers',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/patient-lift-accessories',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/patient-lifts',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/patient-monitors',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/patient-wandering',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/phototherapy-masks',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/physical-therapy-kits',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/pulmonary-assist-devices',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/pulse-oximeter-accessories',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/pulse-oximeters',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/resident-tags-and-pendants',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/stethoscopes',
#  'https://www.grainger.com//category/safety/medical-diagnostics-and-monitoring-equipment/test-lungs',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/air-oxygen-blender-accessories',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/air-oxygen-mixers-and-blenders',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/emergency-oxygen',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/emergency-oxygen-accessories',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/emergency-oxygen-face-masks',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/medical-gas-flow-meters',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/medical-gas-hoses',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/medical-tubing-adapters',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/nasal-cannulas',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/oxygen-therapy-hoods',
#  'https://www.grainger.com//category/safety/medical-oxygen-delivery-and-equipment/oxygen-tubing',
#  'https://www.grainger.com//category/safety/noise-control/noise-control-accessories',
#  'https://www.grainger.com//category/safety/noise-control/sound-proofing-and-acoustical-absorption-products',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/beverage-cooler-cup-dispensers',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/bottled-water',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/cooler-racks',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/coolers',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/hydration-pack-accessories',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/hydration-packs',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/non-insulated-water-jugs',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/portable-cooler-cushions',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/reusable-ice-packs',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/soft-sided-coolers',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/sports-drinks-and-thirst-quenchers',
#  'https://www.grainger.com//category/safety/portable-coolers-and-beverages/water-bottles-and-travel-mugs',
#  'https://www.grainger.com//category/safety/rainwear/flame-resistant-rain-suits',
#  'https://www.grainger.com//category/safety/rainwear/flame-resistant-and-arc-flash-rain-jackets-and-coats',
#  'https://www.grainger.com//category/safety/rainwear/flame-resistant-and-arc-flash-rain-pants-and-overalls',
#  'https://www.grainger.com//category/safety/rainwear/rain-hoods',
#  'https://www.grainger.com//category/safety/rainwear/rain-jackets-and-coats',
#  'https://www.grainger.com//category/safety/rainwear/rain-pants-and-overalls',
#  'https://www.grainger.com//category/safety/rainwear/rain-ponchos',
#  'https://www.grainger.com//category/safety/rainwear/rain-suits',
#  'https://www.grainger.com//category/safety/rainwear/umbrellas',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/canes',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/crutches',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/grooming-and-dressing-aids',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/home-and-dining-aids',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/orthopedic-belts-and-posture-correctors',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/ring-and-seat-cushions',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/rollators',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/stair-chair-accessories',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/stair-chairs',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/traction-equipment',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/walkers',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/wheelchair-parts',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/wheelchair-and-walker-accessories',
#  'https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment/wheelchairs',
#  'https://www.grainger.com//category/safety/respiratory/airline-cooling-systems',
#  'https://www.grainger.com//category/safety/respiratory/airline-filtration-and-co-monitors',
#  'https://www.grainger.com//category/safety/respiratory/breathing-air-cylinder-carts',
#  'https://www.grainger.com//category/safety/respiratory/cartridges-and-filters',
#  'https://www.grainger.com//category/safety/respiratory/cascade-airline-kits-and-manifolds',
#  'https://www.grainger.com//category/safety/respiratory/disposable-respirators-and-dust-masks',
#  'https://www.grainger.com//category/safety/respiratory/emergency-escape-breathing-apparatus',
#  'https://www.grainger.com//category/safety/respiratory/escape-hoods-and-respirators',
#  'https://www.grainger.com//category/safety/respiratory/fit-testing',
#  'https://www.grainger.com//category/safety/respiratory/full-face-respirators',
#  'https://www.grainger.com//category/safety/respiratory/gas-mask-canisters',
#  'https://www.grainger.com//category/safety/respiratory/gas-masks',
#  'https://www.grainger.com//category/safety/respiratory/half-mask-respirators',
#  'https://www.grainger.com//category/safety/respiratory/industrial-scba',
#  'https://www.grainger.com//category/safety/respiratory/papr',
#  'https://www.grainger.com//category/safety/respiratory/papr-accessories',
#  'https://www.grainger.com//category/safety/respiratory/papr-and-supplied-air-hoods-and-helmets',
#  'https://www.grainger.com//category/safety/respiratory/procedural-masks',
#  'https://www.grainger.com//category/safety/respiratory/respirator-accessories',
#  'https://www.grainger.com//category/safety/respiratory/respiratory-airline-hoses',
#  'https://www.grainger.com//category/safety/respiratory/respiratory-cleaning-kits-and-wipes',
#  'https://www.grainger.com//category/safety/respiratory/respiratory-equipment-storage',
#  'https://www.grainger.com//category/safety/respiratory/scba-accessories',
#  'https://www.grainger.com//category/safety/respiratory/scba-backframe-assemblies',
#  'https://www.grainger.com//category/safety/respiratory/scba-and-breathing-air-cylinders',
#  'https://www.grainger.com//category/safety/respiratory/spectacle-kits-and-lens-covers',
#  'https://www.grainger.com//category/safety/respiratory/supplied-air-accessories',
#  'https://www.grainger.com//category/safety/respiratory/supplied-air-compressors-and-ambient-air-pumps',
#  'https://www.grainger.com//category/safety/respiratory/supplied-air-pump-packages',
#  'https://www.grainger.com//category/safety/respiratory/supplied-air-respirators',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/audible-alarm-cover-and-guard-accessories',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/audible-alarm-covers-and-guards',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/audible-alarms',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/carbon-monoxide-and-smoke-alarm-accessories',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/carbon-monoxide-and-smoke-detectors',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/intersection-warning-devices-and-systems',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/lightning-detectors',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/outdoor-warning-systems',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/replacement-flash-tubes-and-strobe-lamps',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/strobe-and-flashing-lights',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/tower-light-accessories',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/tower-light-assemblies',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/tower-light-mounts-and-bases',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/tower-light-sounder-tiers',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/tower-light-tiers',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/warning-light-and-audible-device-accessories',
#  'https://www.grainger.com//category/safety/safety-alarms-and-warnings/weather-radios',
#  'https://www.grainger.com//category/safety/safety-storage/aerosol-can-recycling-equipment',
#  'https://www.grainger.com//category/safety/safety-storage/biohazard-waste-cans',
#  'https://www.grainger.com//category/safety/safety-storage/dispensing-bottles',
#  'https://www.grainger.com//category/safety/safety-storage/marine-fuel-tanks',
#  'https://www.grainger.com//category/safety/safety-storage/safety-cabinets-and-accessories',
#  'https://www.grainger.com//category/safety/safety-storage/safety-cans-and-accessories',
#  'https://www.grainger.com//category/safety/signs/exit-signs-and-retrofit-kits',
#  'https://www.grainger.com//category/safety/signs/fire-and-emergency-situation-signs',
#  'https://www.grainger.com//category/safety/signs/floor-signs',
#  'https://www.grainger.com//category/safety/signs/led-signs-and-message-displays',
#  'https://www.grainger.com//category/safety/signs/led-traffic-signs-and-signals',
#  'https://www.grainger.com//category/safety/signs/no-smoking-signs',
#  'https://www.grainger.com//category/safety/signs/office-and-facility-signs',
#  'https://www.grainger.com//category/safety/signs/parking-and-traffic-signs',
#  'https://www.grainger.com//category/safety/signs/railroad-blue-flag-signs',
#  'https://www.grainger.com//category/safety/signs/road-construction-signs',
#  'https://www.grainger.com//category/safety/signs/safety-record-signs',
#  'https://www.grainger.com//category/safety/signs/safety-signs',
#  'https://www.grainger.com//category/safety/signs/security-signs',
#  'https://www.grainger.com//category/safety/signs/sign-slider-inserts',
#  'https://www.grainger.com//category/safety/signs/sign-slider-message-boards',
#  'https://www.grainger.com//category/safety/signs/sign-supports-and-hardware',
#  'https://www.grainger.com//category/safety/spill-control-supplies/absorbents',
#  'https://www.grainger.com//category/safety/spill-control-supplies/biohazard-spill-kits',
#  'https://www.grainger.com//category/safety/spill-control-supplies/chemical-neutralizers',
#  'https://www.grainger.com//category/safety/spill-control-supplies/collapsible-spill-containment-berms-and-pools',
#  'https://www.grainger.com//category/safety/spill-control-supplies/containment-booms',
#  'https://www.grainger.com//category/safety/spill-control-supplies/drain-covers-and-seals',
#  'https://www.grainger.com//category/safety/spill-control-supplies/drain-plugs',
#  'https://www.grainger.com//category/safety/spill-control-supplies/drip-pans-and-spill-containment-trays',
#  'https://www.grainger.com//category/safety/spill-control-supplies/drum-dispensing-and-containment-systems',
#  'https://www.grainger.com//category/safety/spill-control-supplies/ibc-and-tank-spill-containment',
#  'https://www.grainger.com//category/safety/spill-control-supplies/leak-diverters',
#  'https://www.grainger.com//category/safety/spill-control-supplies/mercury-spill-control',
#  'https://www.grainger.com//category/safety/spill-control-supplies/portable-spill-containment-units',
#  'https://www.grainger.com//category/safety/spill-control-supplies/railroad-spill-containment',
#  'https://www.grainger.com//category/safety/spill-control-supplies/spill-berms-and-accessories',
#  'https://www.grainger.com//category/safety/spill-control-supplies/spill-containment-platform-and-pallet-ramps',
#  'https://www.grainger.com//category/safety/spill-control-supplies/spill-control-accessories',
#  'https://www.grainger.com//category/safety/spill-control-supplies/spill-kits-and-stations',
#  'https://www.grainger.com//category/safety/spill-control-supplies/spill-skids-and-pallets',
#  'https://www.grainger.com//category/safety/spill-control-supplies/stormwater-management',
#  'https://www.grainger.com//category/safety/spill-control-supplies/temporary-leak-repair',
#  'https://www.grainger.com//category/safety/traffic-safety/ada-pads',
#  'https://www.grainger.com//category/safety/traffic-safety/barricade-and-traffic-cone-lights',
#  'https://www.grainger.com//category/safety/traffic-safety/barrier-flagging-and-underground-tape-dispensers',
#  'https://www.grainger.com//category/safety/traffic-safety/barrier-flagging-and-underground-tapes',
#  'https://www.grainger.com//category/safety/traffic-safety/crosswalk-flagger-safety-kits',
#  'https://www.grainger.com//category/safety/traffic-safety/expandable-barrier-accessories',
#  'https://www.grainger.com//category/safety/traffic-safety/flares-and-flare-accessories',
#  'https://www.grainger.com//category/safety/traffic-safety/light-bar-controllers-and-monitors',
#  'https://www.grainger.com//category/safety/traffic-safety/parking-curb-and-speed-bump-accessories',
#  'https://www.grainger.com//category/safety/traffic-safety/parking-curbs-and-speed-bumps',
#  'https://www.grainger.com//category/safety/traffic-safety/pavement-markers-and-pavement-marking-tape',
#  'https://www.grainger.com//category/safety/traffic-safety/property-and-driveway-markers',
#  'https://www.grainger.com//category/safety/traffic-safety/safety-and-security-mirrors',
#  'https://www.grainger.com//category/safety/traffic-safety/solar-flashing-beacons',
#  'https://www.grainger.com//category/safety/traffic-safety/stop-slow-paddles',
#  'https://www.grainger.com//category/safety/traffic-safety/traffic-barrels-and-drums',
#  'https://www.grainger.com//category/safety/traffic-safety/traffic-barricade-and-traffic-cone-accessories',
#  'https://www.grainger.com//category/safety/traffic-safety/traffic-barricades',
#  'https://www.grainger.com//category/safety/traffic-safety/traffic-cones',
#  'https://www.grainger.com//category/safety/traffic-safety/traffic-delineator-posts-and-channelizers',
#  'https://www.grainger.com//category/safety/traffic-safety/traffic-warning-flags-and-banners',
#  'https://www.grainger.com//category/safety/traffic-safety/trench-covers',
#  'https://www.grainger.com//category/safety/traffic-safety/windsock-accessories',
#  'https://www.grainger.com//category/safety/traffic-safety/windsocks',
#  'https://www.grainger.com//category/safety/training/first-aid-training-instruction-guides',
#  'https://www.grainger.com//category/safety/training/hands-on-training-systems',
#  'https://www.grainger.com//category/safety/training/lockout-tagout-training',
#  'https://www.grainger.com//category/safety/training/safety-training-and-reference-materials',
#  'https://www.grainger.com//category/safety/training/training-videos',
#  'https://www.grainger.com//category/safety/water-safety/immersion-survival-and-rescue-suits',
#  'https://www.grainger.com//category/safety/water-safety/inflatable-pfd-rearming-kits',
#  'https://www.grainger.com//category/safety/water-safety/life-jackets-and-pfds',
#  'https://www.grainger.com//category/safety/water-safety/pfd-signal-lights',
#  'https://www.grainger.com//category/safety/water-safety/water-rescue-equipment',
#  'https://www.grainger.com//category/safety/workwear/aprons',
#  'https://www.grainger.com//category/safety/workwear/belts',
#  'https://www.grainger.com//category/safety/workwear/bib-overalls',
#  'https://www.grainger.com//category/safety/workwear/chain-saw-and-protective-chaps',
#  'https://www.grainger.com//category/safety/workwear/cold-weather-headwear-and-liners',
#  'https://www.grainger.com//category/safety/workwear/cooling-vest-inserts',
#  'https://www.grainger.com//category/safety/workwear/cooling-vests-and-jackets',
#  'https://www.grainger.com//category/safety/workwear/cut-resistant-sleeves',
#  'https://www.grainger.com//category/safety/workwear/foot-and-hand-warmers',
#  'https://www.grainger.com//category/safety/workwear/hats',
#  'https://www.grainger.com//category/safety/workwear/headbands-sweatbands-and-cooling-headwear',
#  'https://www.grainger.com//category/safety/workwear/heated-outerwear',
#  'https://www.grainger.com//category/safety/workwear/high-visibility-jackets-and-coats',
#  'https://www.grainger.com//category/safety/workwear/high-visibility-pants',
#  'https://www.grainger.com//category/safety/workwear/high-visibility-shirts-and-sweatshirts',
#  'https://www.grainger.com//category/safety/workwear/jackets-and-coats',
#  'https://www.grainger.com//category/safety/workwear/lab-coats-and-jackets',
#  'https://www.grainger.com//category/safety/workwear/protective-sleeves',
#  'https://www.grainger.com//category/safety/workwear/public-safety-vests',
#  'https://www.grainger.com//category/safety/workwear/reflective-clothing-tape',
#  'https://www.grainger.com//category/safety/workwear/scrubs',
#  'https://www.grainger.com//category/safety/workwear/suspenders',
#  'https://www.grainger.com//category/safety/workwear/sweatshirts',
#  'https://www.grainger.com//category/safety/workwear/t-shirts',
#  'https://www.grainger.com//category/safety/workwear/thermal-underwear',
#  'https://www.grainger.com//category/safety/workwear/traffic-safety-vests',
#  'https://www.grainger.com//category/safety/workwear/wallets',
#  'https://www.grainger.com//category/safety/workwear/work-coveralls',
#  'https://www.grainger.com//category/safety/workwear/work-pants',
#  'https://www.grainger.com//category/safety/workwear/work-shirts',
#  'https://www.grainger.com//category/safety/workwear/work-shorts',
#  'https://www.grainger.com//category/safety/workwear/work-vests']

# %%
#Create the empty list that will hold the urls
all_items_level_4=[]
#For loop to iterate through all urls
for x in skus_level_4:
    #Opening the browser
    browser.visit(x)
    #setting a sleep time between iterations
    time.sleep(2)
    #activating soup
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    #finding the tags that contain the urls
    im=soup.findAll('div',class_='search-list-view__product')
    #Nested loop to iterate through the specific tags in each url
    for i in im:
        #setting an error handling method
        try: 
            #extracting the url of each category on each url
            info=i.attrs['data-url']
        #identifying the error
        except IndexError:
            #printing error message
            print('#-----------')
            print ('No more items')
            
        #appending to the empty list all urls found
        all_items_level_4.append(info)
        #building the end url for each item
        all_urls_items_level_4=[f'https://www.grainger.com/{link}' for link in all_items_level_4]
        
#displaying the results
all_urls_items_level_4

#Converting into a df and saving in a csv file      
df = pd.DataFrame(all_urls_items_level_4)
df.to_csv('all_urls_items_level_4.csv', index=False)

# %% [markdown]
# ## All items Level 5

# %%
import csv
skus_level_5 = []
with open('all_urls_level_5.csv') as file:
    for line in csv.reader(file,delimiter='\t'):
        skus_level_5.append((line[0]))

skus_level_5

# %%
#Create the empty list that will hold the urls
all_items_level_5=[]
#For loop to iterate through all urls
for x in skus_level_5:
    #Opening the browser
    browser.visit(x)
    #setting a sleep time between iterations
    time.sleep(2)
    #activating soup
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    #finding the tags that contain the urls
    im=soup.findAll('div',class_='search-list-view__product')
    #Nested loop to iterate through the specific tags in each url
    for i in im:
        #setting an error handling method
        try: 
            #extracting the url of each category on each url
            info=i.attrs['data-url']
        #identifying the error
        except IndexError:
            #printing error message
            print('#-----------')
            print ('No more items')
            
        #appending to the empty list all urls found
        all_items_level_5.append(info)
        #building the end url for each item
        all_urls_items_level_5=[f'https://www.grainger.com/{link}' for link in all_items_level_5]
        
#displaying the results
all_urls_items_level_5

#Converting into a df and saving in a csv file      
df = pd.DataFrame(all_urls_items_level_5)
df.to_csv('all_urls_items_level_5.csv', index=False)

# %%
price_list=[]
web_price_list=[]
uom_list=[]
sku_list=[]
definition_list=[]
item_list=[]
mfr_model_list=[]
brand_list=[]
country_of_origin=[]
cat_group_list=[]
unspsc_list=[]
item_link_list=[]
cat_link_list=[]
product_text=[]
image_list=[]
compliance_list=[]

level_5=['https://www.grainger.com//category/safety/emergency-preparedness/emergency-lightsticks-and-accessories/emergency-lightstick-accessories',
 'https://www.grainger.com//category/safety/emergency-preparedness/emergency-lightsticks-and-accessories/emergency-lightstick-station-accessories',
 'https://www.grainger.com//category/safety/emergency-preparedness/emergency-lightsticks-and-accessories/emergency-lightstick-stations']

# Iterate through all pages
for x in level_5:
    #Opening the target url and activating soup
    browser.visit(x)
    time.sleep(2)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

try:
    # Retrieve all elements that contain item information from tags
    articles = soup.find_all('span', class_='gcprice-value')
    skus=soup.find('div',class_='price-replace-wrapper')
    lis=soup.findAll('div',class_='head-container clearfix')
    uoms=soup.find('span',class_='gcprice-unit')
    ases=soup.findAll('a',class_='bread-link')
    web=soup.findAll('span',class_='gcprice-label')
    coun=soup.find('div',class_='countryOfOrigin')
    prod=soup.find('div',class_='copyTextSection textSection')
    im=soup.find('div',class_='mainImage').find('img')
    comp=soup.find('div',class_='complianceInfo')
    
    #Extract the information of each item
    price=articles[0].text.strip()
    p= web[0].text.split()[0:2]
    uom=uoms.text
    sku=skus.attrs['data-sku']
    definition=soup.find('h1').text.strip()
    item=lis[0]('span')[0].text
    mfr_model=lis[0]('span')[2].text
    marca=lis[0]('a')[0].text
    country=coun.text.split()[3]
    cat_group=lis[0]('a')[1].text
    unspsc=lis[0]('span')[5].text
    item_link=lis[0]('a')[1]['href']
    lis=ases[2].text
    product=prod.text.strip()
    image=im['src']
    compliance=comp.text.strip()
    

    spe=soup.findAll('span',class_='specValue')
    itemspec=spe[0].text
    material=spe[1].text
    size=spe[2].text
    lenght=spe[3].text
    coating=spe[4].text
    coverage=spe[5].text
    color=spe[6].text
    cuff=spe[7].text
    standard=spe[8].text
    application=spe[9].text
    
    
except:
    print("Table has different settings")
    
else:
    #Append data extracted to the empty lists
    price_list.append(price)
    web_price_list.append(' '.join(p))
    uom_list.append(uom)
    sku_list.append(sku)
    definition_list.append(definition)
    item_list.append(item)
    mfr_model_list.append(mfr_model)
    brand_list.append(marca)
    country_of_origin.append(country)
    cat_group_list.append(cat_group)
    unspsc_list.append(unspsc)
    item_link_list.append(f'https://www.grainger.com/{item_link}')
    cat_link_list.append(lis)
    product_text.append(product)
    image_list.append(image)
    compliance_list.append(comp)
    
 
sku_list

# %%
#Create dataframe for antistatic gloves
df_antistatic_gloves = pd.DataFrame(
    {'SKU': sku_list,
     'Definition': definition_list,
     'Product Description':product_text,
     'Manufacturer Model':mfr_model_list,
     'Brand': brand_list,
     'Category':cat_link_list,
     'Category Group':cat_group_list,
     'UNSPSC':unspsc_list,
     'Price':price_list,
     'Price Type':web_price_list,
     'Country of Origin':country_of_origin,
     'UOM':uom_list,
     'Compliance and Restrictions':compliance_list,
     'Link':item_link_list,
     'Image Link':image_list
    })
df_antistatic_gloves.to_csv('all_safety.csv', encoding='utf-8')
df_antistatic_gloves

# %% [markdown]
# Testing blocks

# %%
url3 ='https://www.grainger.com//category/safety/rehabilitation-and-durable-medical-equipment'
browser.visit(url3)

#activating soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
#For Windows users - Opening the target url
spans = soup.findAll('a', class_='route category-link')
cats=[]
for spa in spans:
    cat=spa['href']
    cats.append(cat)
cats

# %% [markdown]
# Testing blocks
