# %%
## importing bs4, requests, fake_useragent and csv modules
import bs4
import requests
from fake_useragent import UserAgent
import csv

## create an array with URLs
urls = ['https://www.fastenal.com/product/abrasives/coated-and-non-woven-abrasives/fiber-and-sanding-discs/609478?categoryId=609478&level=3&isExpanded=true&productFamilyId=26373&view=1', 
        'https://www.fastenal.com/product/abrasives/coated-and-non-woven-abrasives/fiber-and-sanding-discs/609478?categoryId=609478&level=3&isExpanded=true&productFamilyId=26373&page=2&pageSize=12&exactSkuMatchLevel=useData&view=1',
       'https://www.fastenal.com/product/abrasives/coated-and-non-woven-abrasives/fiber-and-sanding-discs/609478?categoryId=609478&level=3&isExpanded=true&productFamilyId=26373&page=3&pageSize=12&exactSkuMatchLevel=useData&view=1']

## initializing the UserAgent object
user_agent = UserAgent()

## starting the loop
for url in urls:
    ## getting the reponse from the page using get method of requests module
    page = requests.get(url, headers={"user-agent": user_agent.chrome})

    ## storing the content of the page in a variable
    html = page.content

    ## creating BeautifulSoup object
    soup = bs4.BeautifulSoup(html, "html.parser")

    ## Then parse the HTML, extract any data
    ## write it to a file

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html data-epro-user="false" data-custom-catalog-user="false" class="lt-ie10 lt-ie9 lt-ie8 lt-ie7" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://ogp.me/ns/fb#" > <![endif]-->
# <!--[if IE 7]> <html data-epro-user="false" data-custom-catalog-user="false" class="lt-ie10 lt-ie9 lt-ie8" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://ogp.me/ns/fb#" > <![endif]-->
# <!--[if IE 8]> <html data-epro-user="false" data-custom-catalog-user="false" class="lt-ie10 lt-ie9" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://ogp.me/ns/fb#" > <![endif]-->
# <!--[if IE 9]> <html data-epro-user="false" data-custom-catalog-user="false" class="lt-ie10" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://ogp.me/ns/fb#" > <![endif]-->
# ...

# %%
title_containers = soup.find_all('h2',class_="search-list-view__heading")
title_containers
# Out:
# [<h2 class="search-list-view__heading" data-automated-test="descripton--18G411">Dust Collection Bags, PK200</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--18G412">Primary Filter- Filter Sock</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--18G415">Primary Filter- Filter Sock</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--18G418">2 In. Vacuum Hosing</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--18G419">Replacement Air Filter</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--3AA32">Collapsible Drum</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--3AA33">Collapsible Drum</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--3AA34">Hose Extension Kit</h2>,
#  <h2 class="search-list-view__heading" data-automated-test="descripton--3AA35">Hose Extension Kit</h2>,
# ...
