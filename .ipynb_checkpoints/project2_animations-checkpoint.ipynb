# %%
import plotly.plotly as py
from plotly.grid_objs import Grid, Column
from plotly.tools import FigureFactory as FF 

import pandas as pd
import time

dataset = pd.read_csv("vgsales-1970_2019.csv")
dataset.head()

#url = 'vgsales-1970_2019.csv'
#dataset = pd.read_csv(url)

#table = FF.create_table(dataset.head(10))
#py.iplot(table, filename='animations-games-data-preview')
# Out:
#     Rank                                            Name  \
# 0   5337                                            TERA
# 1   7969                Danganronpa: Trigger Happy Havoc
# 2   8513                                 Ghostbusters II
# 3   8559  Valkyria Chronicles III: Unrecorded Chronicles
# 4  15641                                  Check vs. Mate
#
#                                         basename         Genre ESRB_Rating  \
# 0                                           tera  Role-Playing           M
# 1                danganronpa-trigger-happy-havoc     Adventure         NaN
# 2                                ghostbusters-ii        Action         NaN
# 3  valkyria-chronicles-iii-unrecorded-chronicles  Role-Playing          RP
# 4                                  check-vs-mate          Misc           T
#
#   Platform Publisher            Developer  VGChartz_Score  Critic_Score  \
# 0       PC   Unknown             En Masse             NaN           NaN
# 1      PSP   Unknown                Spike             NaN           NaN
# 2     2600   Unknown            Salu Ltd.             NaN           NaN
# 3      PSP   Unknown   Sega WOW Overworks             NaN           NaN
# 4      PS3   Unknown  TopWare Interactive             NaN           NaN
#
#                          ...                          NA_Sales  PAL_Sales  \
# 0                        ...                              0.25       0.13
# 1                        ...                               NaN        NaN
# 2                        ...                              0.20       0.01
# 3                        ...                               NaN        NaN
# 4                        ...                               NaN       0.04
#
#    JP_Sales  Other_Sales    Year  Last_Update  \
# 0       NaN         0.04  1970.0          NaN
# 1      0.24          NaN  1970.0  11th Jan 18
# 2       NaN         0.00  1970.0          NaN
# 3      0.21          NaN  1970.0          NaN
# 4       NaN         0.01  1970.0          NaN
#
#                                                  url  status Vgchartzscore  \
# 0  http://www.vgchartz.com/game/44073/tera/?regio...       1           NaN
# 1  http://www.vgchartz.com/game/46600/danganronpa...       1           NaN
# 2  http://www.vgchartz.com/game/35314/ghostbuster...       1           NaN
# 3  http://www.vgchartz.com/game/47307/valkyria-ch...       1           NaN
# 4  http://www.vgchartz.com/game/45892/check-vs-ma...       1           NaN
#
#                                              img_url
# 0        /games/boxart/full_tera_476AmericaFront.jpg
# 1    /games/boxart/full_dangan-ronpa_0JapanFront.jpg
# 2          /games/boxart/full_1251633PALFrontccc.jpg
# 3  /games/boxart/full_valkyria-chronicles-iii-unr...
# 4  /games/boxart/full_battle-vs-chess_5AmericaFro...
#
# [5 rows x 23 columns]
